# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
mushrooms_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/training_mush.csv')
mushrooms_data.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          2            0          3        1     5                1
# 1          2            0          4        0     5                1
# 2          2            0          3        0     2                1
# 3          0            0          3        0     5                1
# 4          2            3          3        1     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          0           9            1  ...
# 1             0          1          10            0  ...
# 2             0          0           7            0  ...
# 3             1          0           2            0  ...
# 4             0          0          10            1  ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       3                       7          0           2
# ...

# %%
X = mushrooms_data.drop(['class'], axis=1)
y = mushrooms_data[['class']]

# %%
clf_rf = RandomForestClassifier(random_state=0)

# %%
parametres = {'n_estimators': range(10, 50, 10),
              'max_depth': range(1, 12, 2),
              'min_samples_leaf': range(1, 7),
              'min_samples_split': range(2, 9, 2)}

# %%
grid_search_cv = GridSearchCV(clf_rf, parametres, cv=3)

# %%
grid_search_cv.fit(X, y)
# Out:
# C:\Users\aurrog\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\aurrog\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\aurrog\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
best_clf = grid_search_cv.best_estimator_

# %%
grid_search_cv.best_params_
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
feature_importance = best_clf.feature_importances_
feature_importance
# Out:
# array([0.00257742, 0.00312957, 0.02177298, 0.07010933, 0.18837641,
#        0.        , 0.0808402 , 0.06846076, 0.10386114, 0.00756262,
#        0.10379322, 0.03180155, 0.04829594, 0.01768932, 0.00625335,
#        0.        , 0.0108812 , 0.0139101 , 0.07072612, 0.08356419,
#        0.04378343, 0.02261118])

# %%
feature_importance_df = pd.DataFrame({'features': list(X),
                                      'feature_importances': feature_importance})

# %%
feature_importance_df.sort_values('feature_importances', ascending=False)
# Out:
#                     features  feature_importances
# 4                       odor             0.188376
# 8                 gill-color             0.103861
# 10                stalk-root             0.103793
# 19         spore-print-color             0.083564
# 6               gill-spacing             0.080840
# 18                 ring-type             0.070726
# 3                    bruises             0.070109
# 7                  gill-size             0.068461
# 12  stalk-surface-below-ring             0.048296
# 20                population             0.043783
# 11  stalk-surface-above-ring             0.031802
# 21                   habitat             0.022611
# 2                  cap-color             0.021773
# 13    stalk-color-above-ring             0.017689
# 17               ring-number             0.013910
# 16                veil-color             0.010881
# 9                stalk-shape             0.007563
# 14    stalk-color-below-ring             0.006253
# ...

# %%
x_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/testing_mush.csv')

# %%
x_test.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          0            3          8        1     3                1
# 1          5            3          4        1     5                1
# 2          3            3          4        0     8                1
# 3          3            2          2        0     7                1
# 4          3            2          2        0     8                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          0           4            0  ...
# 1             0          0          10            1  ...
# 2             0          1           0            1  ...
# 3             0          1           0            1  ...
# 4             0          1           0            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
predicted = best_clf.predict(x_test)

# %%
print(sum(predicted))
# Out:
# 976

# %%
from sklearn.metrics import confusion_matrix

y_true = pd.read_csv('testing_y_mush.csv')
conf_mat = confusion_matrix(y_true, predicted)

# %%
import seaborn as sns

sns.heatmap(conf_mat, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
war_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/invasion.csv')
war_data.head()
# Out:
#        class  g_reflection  i_reflection       speed  brightness  \
# 0  transport      2.190672      6.716633   62.168208    0.347465
# 1  transport      3.453276      8.995909   62.994707    0.590094
# 2  transport      2.432994      6.938691   62.245807    0.329288
# 3    fighter      6.083763      3.019459   18.474555    0.174738
# 4    fighter     12.876769      2.452950  195.805771    0.150446
#
#    time_of_observance     volume
# 0              158221  44.932446
# 1              385972  41.568300
# 2              446482  40.123467
# 3              210125  11.384865
# 4               23109  11.328806

# %%
transport = {'transport' :  0,  'fighter' :  1,  'cruiser' : 2}

X_train = war_data.drop(['class'], axis=1)
y_train = war_data['class'].map(transport)

# %%
parametres = {'n_estimators': range(10, 50, 10),
              'max_depth': range(1, 12, 2),
              'min_samples_leaf': range(1, 7),
              'min_samples_split': range(2, 9, 2)}

clf_rf = RandomForestClassifier()

# %%
grid_search_cv = GridSearchCV(clf_rf, parametres, cv=3)

# %%
grid_search_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(1, 12, 2),
#                          'min_samples_leaf': range(1, 7),
#                          'min_samples_split': range(2, 9, 2),
#                          'n_estimators': range(10, 50, 10)})

# %%
X_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/operative_information.csv')
X_test.head()
# Out:
#    g_reflection  i_reflection       speed  brightness  time_of_observance  \
# 0      7.516543      3.916691  513.954279    0.177247              105908
# 1      4.322988      6.967689   63.752970    0.545922              277855
# 2      4.595724      9.098297   62.233948    0.389201              160662
# 3      2.689675      7.964869   62.475495    0.541081              162092
# 4      8.075576      5.169719  336.441261    0.174757              466853
#
#       volume
# 0  13.267224
# 1  39.833130
# 2  42.014556
# 3  42.056829
# 4  11.779813

# %%
pd.Series(grid_search_cv.best_estimator_.predict(X_test)).value_counts()
# Out:
# 1    675
# 0    595
# 2    230
# dtype: int64

# %%
pd.DataFrame({'features': list(X_test),
              'feature_importances': grid_search_cv.best_estimator_.feature_importances_}).sort_values('feature_importances', ascending=False)
# Out:
#              features  feature_importances
# 5              volume             0.288595
# 0        g_reflection             0.266935
# 3          brightness             0.227743
# 1        i_reflection             0.188003
# 2               speed             0.028724
# 4  time_of_observance             0.000000

# %%
a = lambda x, y, z: x+y*z
